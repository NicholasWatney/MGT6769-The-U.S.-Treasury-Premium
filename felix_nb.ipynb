# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import os
import getpass
pd.set_option('display.max_columns', None)

desired_username = 'felixlavallee-morissette'
current_username = getpass.getuser()

if current_username == desired_username:
    directory_path = '/Users/felixlavallee-morissette/Downloads/'
    os.chdir(directory_path)
    print(f"Directory changed to {directory_path}")
else:
    print("This is not Felix's computer. Directory change not executed.")
# Out:
# Directory changed to /Users/felixlavallee-morissette/Downloads/

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Fig 1

# %%
df = pd.read_excel("Data_for_project(1).xlsx") 
df
# Out:
#                Start Date 2000-01-01 00:00:00    Unnamed: 2    Unnamed: 3  \
# 0                End Date                 NaN           NaN           NaN
# 1                     NaN                 NaN           NaN           NaN
# 2                     NaN          AUD Curncy  AUD3M Curncy  BBSW3M Index
# 3                     NaN                 NaN           NaN           NaN
# 4                   Dates             PX_LAST       PX_LAST       PX_LAST
# ...                   ...                 ...           ...           ...
# 6327  2024-03-27 00:00:00              0.6535         16.45        4.3436
# 6328  2024-03-28 00:00:00              0.6516         16.56        4.3442
# 6329  2024-03-29 00:00:00              0.6521          16.6        4.3442
# 6330  2024-04-01 00:00:00              0.6489         16.51        4.3442
# 6331  2024-04-02 00:00:00              0.6512         16.59        4.3442
#
#         Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8  \
# 0              NaN           NaN           NaN           NaN           NaN
# 1              NaN           NaN           NaN           NaN           NaN
# 2     ADBS1 Curncy  ADBS2 Curncy  ADBS3 Curncy  ADBS5 Curncy  ADBS7 Curncy
# 3              NaN           NaN           NaN           NaN           NaN
# 4          PX_LAST       PX_LAST       PX_LAST       PX_LAST       PX_LAST
# ...            ...           ...           ...           ...           ...
# 6327          19.5            25         29.13         33.86         35.13
# 6328          19.5            25         29.13         33.86         35.13
# 6329          19.5            25         29.13         33.86         35.13
# 6330          19.5            25         29.13         33.86         35.13
# 6331          19.5            25         29.13         33.86         35.13
#
#          Unnamed: 9      Unnamed: 10      Unnamed: 11      Unnamed: 12  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN              NaN              NaN              NaN
# 2     ADBS10 Curncy  ADSWAP1Q Curncy  ADSWAP2Q Curncy  ADSWAP5Q Curncy
# 3               NaN              NaN              NaN              NaN
# 4           PX_LAST          PX_LAST          PX_LAST          PX_LAST
# ...             ...              ...              ...              ...
# 6327         36.875           4.1665          3.93625           3.8135
# 6328         36.875          4.17476           3.9352           3.8135
# 6329         36.875           4.1705           3.9375           3.8135
# 6330         36.875           4.1705          3.93253           3.8135
# 6331         36.875          4.20308          3.99608           3.9005
#
#           Unnamed: 13     Unnamed: 14     Unnamed: 15     Unnamed: 16  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2     ADSWAP7Q Curncy  ADSWAP1 Curncy  ADSWAP2 Curncy  ADSWAP3 Curncy
# 3                 NaN             NaN             NaN             NaN
# 4             PX_LAST         PX_LAST         PX_LAST         PX_LAST
# ...               ...             ...             ...             ...
# 6327          3.91786         4.37443          4.1333          4.0065
# 6328          3.93483          4.3756           4.128         4.00476
# 6329          3.93483          4.3756           4.128         4.00476
# 6330           3.9325          4.3756           4.128          4.0045
# 6331          4.03177         4.40585         4.19225          4.0765
#
#          Unnamed: 17     Unnamed: 18      Unnamed: 19   Unnamed: 20  \
# 0                NaN             NaN              NaN           NaN
# 1                NaN             NaN              NaN           NaN
# 2     ADSWAP5 Curncy  ADSWAP7 Curncy  ADSWAP10 Curncy  C1273M Index
# 3                NaN             NaN              NaN           NaN
# 4            PX_LAST         PX_LAST          PX_LAST       PX_LAST
# ...              ...             ...              ...           ...
# 6327          3.9905          4.0845          4.22375        4.1453
# 6328         3.98025         4.07775          4.21875        4.1453
# 6329         3.98005         4.07755          4.21875        4.1453
# 6330         3.98005         4.07755          4.21875        4.1453
# 6331          4.0744          4.1822           4.3325        4.1453
#
#        Unnamed: 21   Unnamed: 22   Unnamed: 23   Unnamed: 24   Unnamed: 25  \
# 0              NaN           NaN           NaN           NaN           NaN
# 1              NaN           NaN           NaN           NaN           NaN
# 2     C1271Y Index  C1272Y Index  C1273Y Index  C1275Y Index  C1277Y Index
# 3              NaN           NaN           NaN           NaN           NaN
# 4          PX_LAST       PX_LAST       PX_LAST       PX_LAST       PX_LAST
# ...            ...           ...           ...           ...           ...
# 6327        3.9205        3.6396        3.5297        3.6183        3.8081
# 6328        3.9205        3.6396        3.5297        3.6183        3.8081
# 6329        3.9205        3.6396        3.5297        3.6183        3.8081
# 6330        3.9205        3.6396        3.5297        3.6183        3.8081
# 6331        3.9205        3.6396        3.5297        3.6183        3.8081
#
#         Unnamed: 26
# 0               NaN
# 1               NaN
# 2     C12710Y Index
# 3               NaN
# 4           PX_LAST
# ...             ...
# 6327         4.0024
# 6328         4.0024
# 6329         4.0024
# 6330         4.0024
# 6331         4.0024
#
# [6332 rows x 27 columns]

# %%
df.columns = df.iloc[2]

# Drop the first three rows since they are no longer needed
df = df.drop(df.index[:3])

df
# Out:
# 2                     NaN AUD Curncy AUD3M Curncy BBSW3M Index ADBS1 Curncy  \
# 3                     NaN        NaN          NaN          NaN          NaN
# 4                   Dates    PX_LAST      PX_LAST      PX_LAST      PX_LAST
# 5                     NaN     0.6585          NaN          NaN          NaN
# 6     2000-01-04 00:00:00      0.655          7.4       5.5717          NaN
# 7     2000-01-05 00:00:00     0.6579         7.59        5.615          NaN
# ...                   ...        ...          ...          ...          ...
# 6327  2024-03-27 00:00:00     0.6535        16.45       4.3436         19.5
# 6328  2024-03-28 00:00:00     0.6516        16.56       4.3442         19.5
# 6329  2024-03-29 00:00:00     0.6521         16.6       4.3442         19.5
# 6330  2024-04-01 00:00:00     0.6489        16.51       4.3442         19.5
# 6331  2024-04-02 00:00:00     0.6512        16.59       4.3442         19.5
#
# 2    ADBS2 Curncy ADBS3 Curncy ADBS5 Curncy ADBS7 Curncy ADBS10 Curncy  \
# 3             NaN          NaN          NaN          NaN           NaN
# 4         PX_LAST      PX_LAST      PX_LAST      PX_LAST       PX_LAST
# 5             NaN          NaN          NaN          NaN           NaN
# 6             NaN          NaN          NaN          NaN           NaN
# 7             NaN          NaN          NaN          NaN           NaN
# ...           ...          ...          ...          ...           ...
# 6327           25        29.13        33.86        35.13        36.875
# 6328           25        29.13        33.86        35.13        36.875
# 6329           25        29.13        33.86        35.13        36.875
# 6330           25        29.13        33.86        35.13        36.875
# 6331           25        29.13        33.86        35.13        36.875
#
# 2    ADSWAP1Q Curncy ADSWAP2Q Curncy ADSWAP5Q Curncy ADSWAP7Q Curncy  \
# 3                NaN             NaN             NaN             NaN
# 4            PX_LAST         PX_LAST         PX_LAST         PX_LAST
# 5                NaN             NaN             NaN             NaN
# 6              6.355            6.83           7.275             7.4
# 7               6.31            6.89           7.355         7.38299
# ...              ...             ...             ...             ...
# 6327          4.1665         3.93625          3.8135         3.91786
# 6328         4.17476          3.9352          3.8135         3.93483
# 6329          4.1705          3.9375          3.8135         3.93483
# 6330          4.1705         3.93253          3.8135          3.9325
# 6331         4.20308         3.99608          3.9005         4.03177
#
# 2    ADSWAP1 Curncy ADSWAP2 Curncy ADSWAP3 Curncy ADSWAP5 Curncy  \
# 3               NaN            NaN            NaN            NaN
# 4           PX_LAST        PX_LAST        PX_LAST        PX_LAST
# 5               NaN            NaN            NaN            NaN
# 6               6.4           6.91          7.095           7.35
# 7              6.38           6.91          7.165           7.26
# ...             ...            ...            ...            ...
# 6327        4.37443         4.1333         4.0065         3.9905
# 6328         4.3756          4.128        4.00476        3.98025
# 6329         4.3756          4.128        4.00476        3.98005
# 6330         4.3756          4.128         4.0045        3.98005
# 6331        4.40585        4.19225         4.0765         4.0744
#
# 2    ADSWAP7 Curncy ADSWAP10 Curncy C1273M Index C1271Y Index C1272Y Index  \
# 3               NaN             NaN          NaN          NaN          NaN
# 4           PX_LAST         PX_LAST      PX_LAST      PX_LAST      PX_LAST
# 5               NaN             NaN          NaN          NaN          NaN
# 6              7.44            7.55         4.96         6.12         6.48
# 7              7.48            7.58         5.02         6.09         6.43
# ...             ...             ...          ...          ...          ...
# 6327         4.0845         4.22375       4.1453       3.9205       3.6396
# 6328        4.07775         4.21875       4.1453       3.9205       3.6396
# 6329        4.07755         4.21875       4.1453       3.9205       3.6396
# 6330        4.07755         4.21875       4.1453       3.9205       3.6396
# 6331         4.1822          4.3325       4.1453       3.9205       3.6396
#
# 2    C1273Y Index C1275Y Index C1277Y Index C12710Y Index
# 3             NaN          NaN          NaN           NaN
# 4         PX_LAST      PX_LAST      PX_LAST       PX_LAST
# 5             NaN          NaN          NaN           NaN
# 6            6.66          6.9         7.06          7.14
# 7            6.61         6.84         6.97          7.05
# ...           ...          ...          ...           ...
# 6327       3.5297       3.6183       3.8081        4.0024
# 6328       3.5297       3.6183       3.8081        4.0024
# 6329       3.5297       3.6183       3.8081        4.0024
# 6330       3.5297       3.6183       3.8081        4.0024
# 6331       3.5297       3.6183       3.8081        4.0024
#
# [6329 rows x 27 columns]

# %%
df = df.drop(df.index[:2])
df
# Out:
# 2                     NaN AUD Curncy AUD3M Curncy BBSW3M Index ADBS1 Curncy  \
# 5                     NaN     0.6585          NaN          NaN          NaN
# 6     2000-01-04 00:00:00      0.655          7.4       5.5717          NaN
# 7     2000-01-05 00:00:00     0.6579         7.59        5.615          NaN
# 8     2000-01-06 00:00:00     0.6533         7.62       5.6067          NaN
# 9     2000-01-07 00:00:00     0.6549         7.41       5.5933          NaN
# ...                   ...        ...          ...          ...          ...
# 6327  2024-03-27 00:00:00     0.6535        16.45       4.3436         19.5
# 6328  2024-03-28 00:00:00     0.6516        16.56       4.3442         19.5
# 6329  2024-03-29 00:00:00     0.6521         16.6       4.3442         19.5
# 6330  2024-04-01 00:00:00     0.6489        16.51       4.3442         19.5
# 6331  2024-04-02 00:00:00     0.6512        16.59       4.3442         19.5
#
# 2    ADBS2 Curncy ADBS3 Curncy ADBS5 Curncy ADBS7 Curncy ADBS10 Curncy  \
# 5             NaN          NaN          NaN          NaN           NaN
# 6             NaN          NaN          NaN          NaN           NaN
# 7             NaN          NaN          NaN          NaN           NaN
# 8             NaN          NaN          NaN          NaN           NaN
# 9             NaN          NaN          NaN          NaN           NaN
# ...           ...          ...          ...          ...           ...
# 6327           25        29.13        33.86        35.13        36.875
# 6328           25        29.13        33.86        35.13        36.875
# 6329           25        29.13        33.86        35.13        36.875
# 6330           25        29.13        33.86        35.13        36.875
# 6331           25        29.13        33.86        35.13        36.875
#
# 2    ADSWAP1Q Curncy ADSWAP2Q Curncy ADSWAP5Q Curncy ADSWAP7Q Curncy  \
# 5                NaN             NaN             NaN             NaN
# 6              6.355            6.83           7.275             7.4
# 7               6.31            6.89           7.355         7.38299
# 8               6.35            6.85           7.305           7.415
# 9              6.385           6.865            7.33            7.45
# ...              ...             ...             ...             ...
# 6327          4.1665         3.93625          3.8135         3.91786
# 6328         4.17476          3.9352          3.8135         3.93483
# 6329          4.1705          3.9375          3.8135         3.93483
# 6330          4.1705         3.93253          3.8135          3.9325
# 6331         4.20308         3.99608          3.9005         4.03177
#
# 2    ADSWAP1 Curncy ADSWAP2 Curncy ADSWAP3 Curncy ADSWAP5 Curncy  \
# 5               NaN            NaN            NaN            NaN
# 6               6.4           6.91          7.095           7.35
# 7              6.38           6.91          7.165           7.26
# 8              6.36           6.88          7.115           7.34
# 9             6.385           6.91          7.155          7.355
# ...             ...            ...            ...            ...
# 6327        4.37443         4.1333         4.0065         3.9905
# 6328         4.3756          4.128        4.00476        3.98025
# 6329         4.3756          4.128        4.00476        3.98005
# 6330         4.3756          4.128         4.0045        3.98005
# 6331        4.40585        4.19225         4.0765         4.0744
#
# 2    ADSWAP7 Curncy ADSWAP10 Curncy C1273M Index C1271Y Index C1272Y Index  \
# 5               NaN             NaN          NaN          NaN          NaN
# 6              7.44            7.55         4.96         6.12         6.48
# 7              7.48            7.58         5.02         6.09         6.43
# 8              7.46            7.56         4.96         6.11         6.49
# 9              7.48            7.59         5.01         6.12         6.51
# ...             ...             ...          ...          ...          ...
# 6327         4.0845         4.22375       4.1453       3.9205       3.6396
# 6328        4.07775         4.21875       4.1453       3.9205       3.6396
# 6329        4.07755         4.21875       4.1453       3.9205       3.6396
# 6330        4.07755         4.21875       4.1453       3.9205       3.6396
# 6331         4.1822          4.3325       4.1453       3.9205       3.6396
#
# 2    C1273Y Index C1275Y Index C1277Y Index C12710Y Index
# 5             NaN          NaN          NaN           NaN
# 6            6.66          6.9         7.06          7.14
# 7            6.61         6.84         6.97          7.05
# 8            6.68         6.93         7.08          7.13
# 9            6.71         6.94         7.06          7.12
# ...           ...          ...          ...           ...
# 6327       3.5297       3.6183       3.8081        4.0024
# 6328       3.5297       3.6183       3.8081        4.0024
# 6329       3.5297       3.6183       3.8081        4.0024
# 6330       3.5297       3.6183       3.8081        4.0024
# 6331       3.5297       3.6183       3.8081        4.0024
#
# [6327 rows x 27 columns]

# %%
df = df.rename(columns={df.columns[0]: 'Timestamp'})
df
# Out:
# 2               Timestamp AUD Curncy AUD3M Curncy BBSW3M Index ADBS1 Curncy  \
# 5                     NaN     0.6585          NaN          NaN          NaN
# 6     2000-01-04 00:00:00      0.655          7.4       5.5717          NaN
# 7     2000-01-05 00:00:00     0.6579         7.59        5.615          NaN
# 8     2000-01-06 00:00:00     0.6533         7.62       5.6067          NaN
# 9     2000-01-07 00:00:00     0.6549         7.41       5.5933          NaN
# ...                   ...        ...          ...          ...          ...
# 6327  2024-03-27 00:00:00     0.6535        16.45       4.3436         19.5
# 6328  2024-03-28 00:00:00     0.6516        16.56       4.3442         19.5
# 6329  2024-03-29 00:00:00     0.6521         16.6       4.3442         19.5
# 6330  2024-04-01 00:00:00     0.6489        16.51       4.3442         19.5
# 6331  2024-04-02 00:00:00     0.6512        16.59       4.3442         19.5
#
# 2    ADBS2 Curncy ADBS3 Curncy ADBS5 Curncy ADBS7 Curncy ADBS10 Curncy  \
# 5             NaN          NaN          NaN          NaN           NaN
# 6             NaN          NaN          NaN          NaN           NaN
# 7             NaN          NaN          NaN          NaN           NaN
# 8             NaN          NaN          NaN          NaN           NaN
# 9             NaN          NaN          NaN          NaN           NaN
# ...           ...          ...          ...          ...           ...
# 6327           25        29.13        33.86        35.13        36.875
# 6328           25        29.13        33.86        35.13        36.875
# 6329           25        29.13        33.86        35.13        36.875
# 6330           25        29.13        33.86        35.13        36.875
# 6331           25        29.13        33.86        35.13        36.875
#
# 2    ADSWAP1Q Curncy ADSWAP2Q Curncy ADSWAP5Q Curncy ADSWAP7Q Curncy  \
# 5                NaN             NaN             NaN             NaN
# 6              6.355            6.83           7.275             7.4
# 7               6.31            6.89           7.355         7.38299
# 8               6.35            6.85           7.305           7.415
# 9              6.385           6.865            7.33            7.45
# ...              ...             ...             ...             ...
# 6327          4.1665         3.93625          3.8135         3.91786
# 6328         4.17476          3.9352          3.8135         3.93483
# 6329          4.1705          3.9375          3.8135         3.93483
# 6330          4.1705         3.93253          3.8135          3.9325
# 6331         4.20308         3.99608          3.9005         4.03177
#
# 2    ADSWAP1 Curncy ADSWAP2 Curncy ADSWAP3 Curncy ADSWAP5 Curncy  \
# 5               NaN            NaN            NaN            NaN
# 6               6.4           6.91          7.095           7.35
# 7              6.38           6.91          7.165           7.26
# 8              6.36           6.88          7.115           7.34
# 9             6.385           6.91          7.155          7.355
# ...             ...            ...            ...            ...
# 6327        4.37443         4.1333         4.0065         3.9905
# 6328         4.3756          4.128        4.00476        3.98025
# 6329         4.3756          4.128        4.00476        3.98005
# 6330         4.3756          4.128         4.0045        3.98005
# 6331        4.40585        4.19225         4.0765         4.0744
#
# 2    ADSWAP7 Curncy ADSWAP10 Curncy C1273M Index C1271Y Index C1272Y Index  \
# 5               NaN             NaN          NaN          NaN          NaN
# 6              7.44            7.55         4.96         6.12         6.48
# 7              7.48            7.58         5.02         6.09         6.43
# 8              7.46            7.56         4.96         6.11         6.49
# 9              7.48            7.59         5.01         6.12         6.51
# ...             ...             ...          ...          ...          ...
# 6327         4.0845         4.22375       4.1453       3.9205       3.6396
# 6328        4.07775         4.21875       4.1453       3.9205       3.6396
# 6329        4.07755         4.21875       4.1453       3.9205       3.6396
# 6330        4.07755         4.21875       4.1453       3.9205       3.6396
# 6331         4.1822          4.3325       4.1453       3.9205       3.6396
#
# 2    C1273Y Index C1275Y Index C1277Y Index C12710Y Index
# 5             NaN          NaN          NaN           NaN
# 6            6.66          6.9         7.06          7.14
# 7            6.61         6.84         6.97          7.05
# 8            6.68         6.93         7.08          7.13
# 9            6.71         6.94         7.06          7.12
# ...           ...          ...          ...           ...
# 6327       3.5297       3.6183       3.8081        4.0024
# 6328       3.5297       3.6183       3.8081        4.0024
# 6329       3.5297       3.6183       3.8081        4.0024
# 6330       3.5297       3.6183       3.8081        4.0024
# 6331       3.5297       3.6183       3.8081        4.0024
#
# [6327 rows x 27 columns]

# %%
au = df[['Timestamp', 'C1275Y Index']]
au
# Out:
# 2               Timestamp C1275Y Index
# 5                     NaN          NaN
# 6     2000-01-04 00:00:00          6.9
# 7     2000-01-05 00:00:00         6.84
# 8     2000-01-06 00:00:00         6.93
# 9     2000-01-07 00:00:00         6.94
# ...                   ...          ...
# 6327  2024-03-27 00:00:00       3.6183
# 6328  2024-03-28 00:00:00       3.6183
# 6329  2024-03-29 00:00:00       3.6183
# 6330  2024-04-01 00:00:00       3.6183
# 6331  2024-04-02 00:00:00       3.6183
#
# [6327 rows x 2 columns]

# %%
plt.plot(au['Timestamp'], au['C1275Y Index'])
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 plt.plot(au['Timestamp'], au['C1275Y Index'])
#       2 plt.grid(True)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:2327, in _AxesBase._update_line_limits(self, line)
#    2323 def _update_line_limits(self, line):
#    2324     """
#    2325     Figures out the data limit of the given line, updating self.dataLim.
#    2326     """
# -> 2327     path = line.get_path()
#    2328     if path.vertices.size == 0:
#    2329         return
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/lines.py:1028, in Line2D.get_path(self)
#    1026 """Return the `~matplotlib.path.Path` associated with this line."""
#    1027 if self._invalidy or self._invalidx:
# -> 1028     self.recache()
#    1029 return self._path
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/lines.py:659, in Line2D.recache(self, always)
#     657 if always or self._invalidx:
#     658     xconv = self.convert_xunits(self._xorig)
# --> 659     x = _to_unmasked_float_array(xconv).ravel()
#     660 else:
#     661     x = self._x
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1340, in _to_unmasked_float_array(x)
#    1338     return np.ma.asarray(x, float).filled(np.nan)
#    1339 else:
# -> 1340     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a real number, not 'datetime.datetime'

# %% [markdown]
# ## Combine all G10 countries and USD

# %%
sheets_dict = pd.read_excel("Data_with_usd.xlsx", sheet_name=None)

# Access each DataFrame using the sheet name as key
df_cad = sheets_dict['CAD']
df_chf = sheets_dict['CHF']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sheets_dict = pd.read_excel("Data_with_usd.xlsx", sheet_name=None)
#       3 # Access each DataFrame using the sheet name as key
#       4 df_cad = sheets_dict['CAD']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:1496, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1494     ext = "xls"
#    1495 else:
# -> 1496     ext = inspect_excel_format(
#    1497         content_or_path=path_or_buffer, storage_options=storage_options
#    1498     )
#    1499     if ext is None:
#    1500         raise ValueError(
#    1501             "Excel file format cannot be determined, you must specify "
#    1502             "an engine manually."
#    1503         )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:1371, in inspect_excel_format(content_or_path, storage_options)
#    1368 if isinstance(content_or_path, bytes):
#    1369     content_or_path = BytesIO(content_or_path)
# -> 1371 with get_handle(
#    1372     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1373 ) as handle:
#    1374     stream = handle.handle
#    1375     stream.seek(0)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data_with_usd.xlsx'

# %%
df_cad.columns = df_cad.iloc[2]
df_cad = df_cad.drop(df_cad.index[:3])
df_cad = df_cad.drop(df_cad.index[:2])
df_cad = df_cad.rename(columns={df_cad.columns[0]: 'Timestamp'})
cad = df_cad[['Timestamp', 'C1015Y Index']]

# %%
df_chf.columns = df_chf.iloc[2]
df_chf = df_chf.drop(df_chf.index[:3])
df_chf = df_chf.drop(df_chf.index[:2])
df_chf = df_chf.rename(columns={df_chf.columns[0]: 'Timestamp'})
chf = df_chf[['Timestamp', 'C2565Y Index']]

# %%
# Access each DataFrame using the sheet name as key
df_usd = sheets_dict['USD']

# Process USD DataFrame
df_usd.columns = df_usd.iloc[2]
df_usd = df_usd.drop(df_usd.index[:3])
df_usd = df_usd.drop(df_usd.index[:2])
df_usd = df_usd.rename(columns={df_usd.columns[0]: 'Timestamp'})
usd = df_usd[['Timestamp', 'C0825Y Index']]  # Replace 'CXXXXY Index' with actual column name for USD

# %%
pd.Series(au['C1275Y Index']).rolling(window=7).mean().dropna()
# Out:
# 12      6.944286
# 13      6.962857
# 14      6.990000
# 15      7.007143
# 16      7.020000
#           ...
# 6327    3.618300
# 6328    3.618300
# 6329    3.618300
# 6330    3.618300
# 6331    3.618300
# Name: C1275Y Index, Length: 6320, dtype: float64

# %%
# Plotting
plt.figure(figsize=(15, 6))
plt.plot(au['Timestamp'][7:], pd.Series(au['C1275Y Index']).rolling(window=7).mean().dropna(), label='AUD')
plt.plot(cad['Timestamp'][7:], pd.Series(cad['C1015Y Index']).rolling(window=7).mean().dropna(), label='CAD')
plt.plot(chf['Timestamp'][7:], pd.Series(chf['C2565Y Index']).rolling(window=7).mean().dropna(), label='CHF')
plt.plot(usd['Timestamp'][7:], pd.Series(usd['C0825Y Index']).rolling(window=7).mean().dropna(), label='USD') 
plt.ylabel('Percent')
plt.legend()
plt.grid(True)
plt.savefig('images/fig1a')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       2 plt.figure(figsize=(15, 6))
#       3 plt.plot(au['Timestamp'][7:], pd.Series(au['C1275Y Index']).rolling(window=7).mean().dropna(), label='AUD')
# ----> 4 plt.plot(cad['Timestamp'][7:], pd.Series(cad['C1015Y Index']).rolling(window=7).mean().dropna(), label='CAD')
#       5 plt.plot(chf['Timestamp'][7:], pd.Series(chf['C2565Y Index']).rolling(window=7).mean().dropna(), label='CHF')
#       6 plt.plot(usd['Timestamp'][7:], pd.Series(usd['C0825Y Index']).rolling(window=7).mean().dropna(), label='USD')
#
# NameError: name 'cad' is not defined

# %% [markdown]
# ## Getting the variable: forward premium

# %%
aud_irs = df['ADSWAP5Q Curncy']
aud_bs = df['ADBS5 Curncy'] / 100  # Divide by 100
usd_irs = df_usd['USSW5 Curncy']

# %%
usd_irs = usd_irs.iloc[:-1]

# %%
usd_irs_gfc = usd_irs.iloc[3106:]
usd_irs_gfc
# Out:
# 3111     1.345
# 3112     1.321
# 3113    1.3655
# 3114     1.328
# 3115     1.321
#          ...
# 6327     4.219
# 6328     4.219
# 6329     4.219
# 6330     4.219
# 6331     4.219
# Name: USSW5 Curncy, Length: 3221, dtype: object

# %%
aud_irs_gfc = aud_irs.iloc[3106:]
aud_irs_gfc
# Out:
# 3111     4.225
# 3112      4.18
# 3113     4.226
# 3114    4.2985
# 3115     4.255
#          ...
# 6327    3.8135
# 6328    3.8135
# 6329    3.8135
# 6330    3.8135
# 6331    3.9005
# Name: ADSWAP5Q Curncy, Length: 3221, dtype: object

# %%
aud_bs = aud_bs.dropna()
aud_bs
# Out:
# 3111     0.145
# 3112     0.173
# 3113    0.2125
# 3114     0.213
# 3115     0.209
#          ...
# 6327    0.3386
# 6328    0.3386
# 6329    0.3386
# 6330    0.3386
# 6331    0.3386
# Name: ADBS5 Curncy, Length: 3221, dtype: object

# %%
forward_premium_au = aud_irs_gfc + aud_bs - usd_irs_gfc

# %%
ts = au['Timestamp'][3106:]
ts
# Out:
# 3111    2011-11-29 00:00:00
# 3112    2011-11-30 00:00:00
# 3113    2011-12-01 00:00:00
# 3114    2011-12-02 00:00:00
# 3115    2011-12-05 00:00:00
#                ...
# 6327    2024-03-27 00:00:00
# 6328    2024-03-28 00:00:00
# 6329    2024-03-29 00:00:00
# 6330    2024-04-01 00:00:00
# 6331    2024-04-02 00:00:00
# Name: Timestamp, Length: 3221, dtype: object

# %%
plt.plot(ts, forward_premium_au, label='AUD')

# %% [markdown]
# ## Plot synthetic dollar yields

# %%
au_gfc = au['C1275Y Index'][3106:]

# %%
plt.plot(ts, au_gfc-forward_premium_au, label='AUD')

# %% [markdown]
# ### Get forward premium variables for other countries

# %%
cad_irs = df_cad['CDSW5 Curncy']
cad_bs = df_cad['CDBS5 Curncy'] / 100  # Divide by 100

# %%
cad_bs_gfc = cad_bs[2542:]
cad_bs_gfc
# Out:
# 2547     0.145
# 2548     0.145
# 2549     0.145
# 2550     0.145
# 2551     0.145
#          ...
# 6327   -0.1025
# 6328    -0.115
# 6329    -0.105
# 6330   -0.1075
# 6331    -0.105
# Name: CDBS5 Curncy, Length: 3785, dtype: object

# %%
cad_irs_gfc = cad_irs[2542:]
cad_irs_gfc
# Out:
# 2547    2.6345
# 2548     2.578
# 2549     2.551
# 2550     2.554
# 2551     2.624
#          ...
# 6327    3.8295
# 6328     3.859
# 6329     3.859
# 6330    3.9625
# 6331    3.9753
# Name: CDSW5 Curncy, Length: 3785, dtype: object

# %%
usd_irs = usd_irs.dropna()
usd_irs
# Out:
# 2547    2.6485
# 2548    2.5335
# 2549      2.56
# 2550    2.5805
# 2551     2.619
#          ...
# 6327     4.219
# 6328     4.219
# 6329     4.219
# 6330     4.219
# 6331     4.219
# Name: USSW5 Curncy, Length: 3785, dtype: object

# %%
def get_forward_premium(irs, bs, usirs=usd_irs):
    return irs+bs-usirs


forward_premium_cad = get_forward_premium(cad_irs_gfc, cad_bs_gfc)

# %%
ts_cad = au['Timestamp'][2542:]
ts_cad
# Out:
# 2547    2009-09-30 00:00:00
# 2548    2009-10-01 00:00:00
# 2549    2009-10-02 00:00:00
# 2550    2009-10-05 00:00:00
# 2551    2009-10-06 00:00:00
#                ...
# 6327    2024-03-27 00:00:00
# 6328    2024-03-28 00:00:00
# 6329    2024-03-29 00:00:00
# 6330    2024-04-01 00:00:00
# 6331    2024-04-02 00:00:00
# Name: Timestamp, Length: 3785, dtype: object

# %%
cad_gfc = cad['C1015Y Index'][2542:]

# %%
plt.plot(ts, au_gfc-forward_premium_au, label='AUD')
plt.plot(ts_cad, cad_gfc-forward_premium_cad, label='CAD')
plt.ylabel('Percent')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Forward premium: CHF

# %%
chf_irs = df_chf['SFSW5V3 Curncy']
chf_bs = df_chf['SFBS5 Curncy'] / 100  # Divide by 100

# %%
chf_irs.dropna()
# Out:
# 2548     1.533
# 2549     1.535
# 2550     1.535
# 2551     1.553
# 2552      1.54
#          ...
# 6327   -0.2325
# 6328   -0.2325
# 6329   -0.2325
# 6330   -0.2325
# 6331   -0.2325
# Name: SFSW5V3 Curncy, Length: 3784, dtype: object

# %%
chf_bs.dropna()
# Out:
# 2962   -0.240445
# 2963   -0.241931
# 2964       -0.23
# 2965       -0.23
# 2966       -0.23
#           ...
# 6327     -0.0725
# 6328     -0.0725
# 6329     -0.0725
# 6330     -0.0725
# 6331     -0.0725
# Name: SFBS5 Curncy, Length: 3370, dtype: object

# %%
chf_bs_gfc = chf_bs[2957:]
chf_bs_gfc
# Out:
# 2962   -0.240445
# 2963   -0.241931
# 2964       -0.23
# 2965       -0.23
# 2966       -0.23
#           ...
# 6327     -0.0725
# 6328     -0.0725
# 6329     -0.0725
# 6330     -0.0725
# 6331     -0.0725
# Name: SFBS5 Curncy, Length: 3370, dtype: object

# %%
chf_irs_gfc = chf_irs[2957:]
chf_irs_gfc
# Out:
# 2962    1.5665
# 2963     1.498
# 2964     1.485
# 2965     1.445
# 2966     1.418
#          ...
# 6327   -0.2325
# 6328   -0.2325
# 6329   -0.2325
# 6330   -0.2325
# 6331   -0.2325
# Name: SFSW5V3 Curncy, Length: 3370, dtype: object

# %%
ts_chf = au['Timestamp'][2957:]
ts_chf
# Out:
# 2962    2011-05-04 00:00:00
# 2963    2011-05-05 00:00:00
# 2964    2011-05-06 00:00:00
# 2965    2011-05-09 00:00:00
# 2966    2011-05-10 00:00:00
#                ...
# 6327    2024-03-27 00:00:00
# 6328    2024-03-28 00:00:00
# 6329    2024-03-29 00:00:00
# 6330    2024-04-01 00:00:00
# 6331    2024-04-02 00:00:00
# Name: Timestamp, Length: 3370, dtype: object

# %%
usd_chf = usd_irs[415:]
usd_chf
# Out:
# 2962      2.12
# 2963    2.0676
# 2964     2.054
# 2965    2.0395
# 2966     2.108
#          ...
# 6327     4.219
# 6328     4.219
# 6329     4.219
# 6330     4.219
# 6331     4.219
# Name: USSW5 Curncy, Length: 3370, dtype: object

# %%
forward_premium_chf = get_forward_premium(chf_irs_gfc, chf_bs_gfc, usd_chf)

# %%
chf_gfc = chf['C2565Y Index'][2957:]

# %%
usd['Timestamp'][2537:]
# Out:
# 2542    2009-09-23 00:00:00
# 2543    2009-09-24 00:00:00
# 2544    2009-09-25 00:00:00
# 2545    2009-09-28 00:00:00
# 2546    2009-09-29 00:00:00
#                ...
# 6328    2024-03-28 00:00:00
# 6329    2024-03-29 00:00:00
# 6330    2024-04-01 00:00:00
# 6331    2024-04-02 00:00:00
# 6332    2024-04-03 00:00:00
# Name: Timestamp, Length: 3791, dtype: object

# %%
plt.figure(figsize=(15, 6))
plt.plot(ts, au_gfc-forward_premium_au, label='AUD')
plt.plot(ts_cad, cad_gfc-forward_premium_cad, label='CAD')
plt.plot(ts_chf, chf_gfc-forward_premium_chf, label='CHF')
plt.plot(usd['Timestamp'][2537:], usd['C0825Y Index'][2537:], label='USD') 
plt.ylabel('Percent')
plt.legend()
plt.grid(True)
plt.savefig('images/fig1b')

# %%
synthetic_aud = au_gfc-forward_premium_au
synthetic_cad = cad_gfc-forward_premium_cad
synthetic_chf = chf_gfc-forward_premium_chf

# %% [markdown]
# # Fig 3

# %%
def ustp(synthetic, govt_us):
    a = len(synthetic)
    b = len(govt_us)
    
    l = min(a,b)
    synthetic = synthetic.tail(l)
    govt_us = govt_us.tail(l)
    
    return (synthetic - govt_us)*100

# %%
synthetic_aud
# Out:
# 3111    0.3904
# 3112    0.3299
# 3113    0.4459
# 3114    0.3214
# 3115    0.3486
#          ...
# 6327    3.6852
# 6328    3.6852
# 6329    3.6852
# 6330    3.6852
# 6331    3.5982
# Length: 3221, dtype: object

# %%
govt_us = usd['C0825Y Index'].drop(usd.index[-1])

# %%
govt_us
# Out:
# 5          6.5
# 6         6.39
# 7         6.48
# 8         6.42
# 9         6.42
#          ...
# 6327    4.0159
# 6328    4.0159
# 6329    4.0159
# 6330    4.0159
# 6331    4.0159
# Name: C0825Y Index, Length: 6327, dtype: object

# %%
ustp_aud = ustp(synthetic_aud, govt_us)

# %%
plt.figure(figsize=(15, 6))
plt.plot(ts, ustp_au, label='AUD')
plt.ylabel('Basis Points')
plt.title("AUD")
plt.grid(True)
plt.savefig('images/fig3_aud')

# %%
ustp_cad = ustp(synthetic_cad, govt_us)
plt.figure(figsize=(15, 6))
plt.plot(ts_cad, ustp_cad)
plt.ylabel('Basis Points')
plt.title("CAD")
plt.grid(True)
plt.savefig('images/fig3_cad')

# %%
ustp_chf = ustp(synthetic_chf, govt_us)
plt.figure(figsize=(15, 6))
plt.plot(ts_chf, ustp_chf)
plt.ylabel('Basis Points')
plt.title("CHF")
plt.grid(True)
plt.savefig('images/fig3_chf')

# %% [markdown]
# # Fig 2

# %%
ustp_mean = (ustp_chf + ustp_cad + ustp_aud) / 3
ustp_mean = ustp_mean.dropna()

# %%
ustp_mean
# Out:
# 3111        21.38
# 3112    12.706667
# 3113    15.843333
# 3114        14.84
# 3115        12.24
#           ...
# 6327    30.256667
# 6328        29.69
# 6329    29.356667
# 6330        25.99
# 6331        22.58
# Length: 3221, dtype: object

# %%
plt.figure(figsize=(15, 6))
plt.plot(ts, ustp_mean)
plt.ylabel('Basis Points')
plt.title("Cross-country Mean of the 5-year US Treasury Premium - AUD, CAD, CHF")
plt.grid(True)
plt.savefig('images/fig2')
