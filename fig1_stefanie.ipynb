# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Data_for_project.xlsx") 
df
# Out:
#                Start Date      2000-01-01 00:00:00               Unnamed: 2  \
# 0                End Date                      NaN                      NaN
# 1                     NaN                      NaN                      NaN
# 2                     NaN               AUD Curncy             AUD3M Curncy
# 3                     NaN  #N/A Requesting Data...  #N/A Requesting Data...
# 4                   Dates                  PX_LAST                  PX_LAST
# ...                   ...                      ...                      ...
# 6327  2024-03-27 00:00:00                   0.6535                    16.45
# 6328  2024-03-28 00:00:00                   0.6516                    16.56
# 6329  2024-03-29 00:00:00                   0.6521                     16.6
# 6330  2024-04-01 00:00:00                   0.6489                    16.51
# 6331  2024-04-02 00:00:00                   0.6512                    16.59
#
#                    Unnamed: 3               Unnamed: 4  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                BBSW3M Index             ADBS1 Curncy
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# ...                       ...                      ...
# 6327                   4.3436                     19.5
# 6328                   4.3442                     19.5
# 6329                   4.3442                     19.5
# 6330                   4.3442                     19.5
# 6331                   4.3442                     19.5
#
#                    Unnamed: 5               Unnamed: 6  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                ADBS2 Curncy             ADBS3 Curncy
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# ...                       ...                      ...
# 6327                       25                    29.13
# 6328                       25                    29.13
# 6329                       25                    29.13
# 6330                       25                    29.13
# 6331                       25                    29.13
#
#                    Unnamed: 7               Unnamed: 8  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                ADBS5 Curncy             ADBS7 Curncy
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# ...                       ...                      ...
# 6327                    33.86                    35.13
# 6328                    33.86                    35.13
# 6329                    33.86                    35.13
# 6330                    33.86                    35.13
# 6331                    33.86                    35.13
#
#                    Unnamed: 9  ...              Unnamed: 17  \
# 0                         NaN  ...                      NaN
# 1                         NaN  ...                      NaN
# 2               ADBS10 Curncy  ...           ADSWAP5 Curncy
# 3     #N/A Requesting Data...  ...  #N/A Requesting Data...
# 4                     PX_LAST  ...                  PX_LAST
# ...                       ...  ...                      ...
# 6327                   36.875  ...                   3.9905
# 6328                   36.875  ...                  3.98025
# 6329                   36.875  ...                  3.98005
# 6330                   36.875  ...                  3.98005
# 6331                   36.875  ...                   4.0744
#
#                   Unnamed: 18              Unnamed: 19  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2              ADSWAP7 Curncy          ADSWAP10 Curncy
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# ...                       ...                      ...
# 6327                   4.0845                  4.22375
# 6328                  4.07775                  4.21875
# 6329                  4.07755                  4.21875
# 6330                  4.07755                  4.21875
# 6331                   4.1822                   4.3325
#
#                   Unnamed: 20              Unnamed: 21  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                C1273M Index             C1271Y Index
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# ...                       ...                      ...
# 6327                   4.1453                   3.9205
# 6328                   4.1453                   3.9205
# 6329                   4.1453                   3.9205
# 6330                   4.1453                   3.9205
# 6331                   4.1453                   3.9205
#
#                   Unnamed: 22              Unnamed: 23  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                C1272Y Index             C1273Y Index
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# ...                       ...                      ...
# 6327                   3.6396                   3.5297
# 6328                   3.6396                   3.5297
# 6329                   3.6396                   3.5297
# 6330                   3.6396                   3.5297
# 6331                   3.6396                   3.5297
#
#                   Unnamed: 24              Unnamed: 25  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                C1275Y Index             C1277Y Index
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# ...                       ...                      ...
# 6327                   3.6183                   3.8081
# 6328                   3.6183                   3.8081
# 6329                   3.6183                   3.8081
# 6330                   3.6183                   3.8081
# 6331                   3.6183                   3.8081
#
#                   Unnamed: 26
# 0                         NaN
# 1                         NaN
# 2               C12710Y Index
# 3     #N/A Requesting Data...
# 4                     PX_LAST
# ...                       ...
# 6327                   4.0024
# 6328                   4.0024
# 6329                   4.0024
# 6330                   4.0024
# 6331                   4.0024
#
# [6332 rows x 27 columns]

# %%
df.columns = df.iloc[2]

# Drop the first three rows since they are no longer needed
df = df.drop(df.index[:3])

df
# Out:
# 2                     NaN               AUD Curncy             AUD3M Curncy  \
# 3                     NaN  #N/A Requesting Data...  #N/A Requesting Data...
# 4                   Dates                  PX_LAST                  PX_LAST
# 5     2000-01-03 00:00:00                   0.6585                     6.75
# 6     2000-01-04 00:00:00                    0.655                      7.4
# 7     2000-01-05 00:00:00                   0.6579                     7.59
# ...                   ...                      ...                      ...
# 6327  2024-03-27 00:00:00                   0.6535                    16.45
# 6328  2024-03-28 00:00:00                   0.6516                    16.56
# 6329  2024-03-29 00:00:00                   0.6521                     16.6
# 6330  2024-04-01 00:00:00                   0.6489                    16.51
# 6331  2024-04-02 00:00:00                   0.6512                    16.59
#
# 2                BBSW3M Index             ADBS1 Curncy  \
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# 5                      5.7383                      NaN
# 6                      5.5717                      NaN
# 7                       5.615                      NaN
# ...                       ...                      ...
# 6327                   4.3436                     19.5
# 6328                   4.3442                     19.5
# 6329                   4.3442                     19.5
# 6330                   4.3442                     19.5
# 6331                   4.3442                     19.5
#
# 2                ADBS2 Curncy             ADBS3 Curncy  \
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# 5                         NaN                      NaN
# 6                         NaN                      NaN
# 7                         NaN                      NaN
# ...                       ...                      ...
# 6327                       25                    29.13
# 6328                       25                    29.13
# 6329                       25                    29.13
# 6330                       25                    29.13
# 6331                       25                    29.13
#
# 2                ADBS5 Curncy             ADBS7 Curncy  \
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# 5                         NaN                      NaN
# 6                         NaN                      NaN
# 7                         NaN                      NaN
# ...                       ...                      ...
# 6327                    33.86                    35.13
# 6328                    33.86                    35.13
# 6329                    33.86                    35.13
# 6330                    33.86                    35.13
# 6331                    33.86                    35.13
#
# 2               ADBS10 Curncy  ...           ADSWAP5 Curncy  \
# 3     #N/A Requesting Data...  ...  #N/A Requesting Data...
# 4                     PX_LAST  ...                  PX_LAST
# 5                         NaN  ...                   7.2375
# 6                         NaN  ...                     7.35
# 7                         NaN  ...                     7.26
# ...                       ...  ...                      ...
# 6327                   36.875  ...                   3.9905
# 6328                   36.875  ...                  3.98025
# 6329                   36.875  ...                  3.98005
# 6330                   36.875  ...                  3.98005
# 6331                   36.875  ...                   4.0744
#
# 2              ADSWAP7 Curncy          ADSWAP10 Curncy  \
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# 5                        7.53                     7.64
# 6                        7.44                     7.55
# 7                        7.48                     7.58
# ...                       ...                      ...
# 6327                   4.0845                  4.22375
# 6328                  4.07775                  4.21875
# 6329                  4.07755                  4.21875
# 6330                  4.07755                  4.21875
# 6331                   4.1822                   4.3325
#
# 2                C1273M Index             C1271Y Index  \
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# 5                        4.92                        6
# 6                        4.96                     6.12
# 7                        5.02                     6.09
# ...                       ...                      ...
# 6327                   4.1453                   3.9205
# 6328                   4.1453                   3.9205
# 6329                   4.1453                   3.9205
# 6330                   4.1453                   3.9205
# 6331                   4.1453                   3.9205
#
# 2                C1272Y Index             C1273Y Index  \
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# 5                        6.29                     6.47
# 6                        6.48                     6.66
# 7                        6.43                     6.61
# ...                       ...                      ...
# 6327                   3.6396                   3.5297
# 6328                   3.6396                   3.5297
# 6329                   3.6396                   3.5297
# 6330                   3.6396                   3.5297
# 6331                   3.6396                   3.5297
#
# 2                C1275Y Index             C1277Y Index  \
# 3     #N/A Requesting Data...  #N/A Requesting Data...
# 4                     PX_LAST                  PX_LAST
# 5                        6.72                     6.91
# 6                         6.9                     7.06
# 7                        6.84                     6.97
# ...                       ...                      ...
# 6327                   3.6183                   3.8081
# 6328                   3.6183                   3.8081
# 6329                   3.6183                   3.8081
# 6330                   3.6183                   3.8081
# 6331                   3.6183                   3.8081
#
# 2               C12710Y Index
# 3     #N/A Requesting Data...
# 4                     PX_LAST
# 5                        6.97
# 6                        7.14
# 7                        7.05
# ...                       ...
# 6327                   4.0024
# 6328                   4.0024
# 6329                   4.0024
# 6330                   4.0024
# 6331                   4.0024
#
# [6329 rows x 27 columns]

# %%
df = df.drop(df.index[:2])
df
# Out:
# 2                     NaN AUD Curncy AUD3M Curncy BBSW3M Index ADBS1 Curncy  \
# 5     2000-01-03 00:00:00     0.6585         6.75       5.7383          NaN
# 6     2000-01-04 00:00:00      0.655          7.4       5.5717          NaN
# 7     2000-01-05 00:00:00     0.6579         7.59        5.615          NaN
# 8     2000-01-06 00:00:00     0.6533         7.62       5.6067          NaN
# 9     2000-01-07 00:00:00     0.6549         7.41       5.5933          NaN
# ...                   ...        ...          ...          ...          ...
# 6327  2024-03-27 00:00:00     0.6535        16.45       4.3436         19.5
# 6328  2024-03-28 00:00:00     0.6516        16.56       4.3442         19.5
# 6329  2024-03-29 00:00:00     0.6521         16.6       4.3442         19.5
# 6330  2024-04-01 00:00:00     0.6489        16.51       4.3442         19.5
# 6331  2024-04-02 00:00:00     0.6512        16.59       4.3442         19.5
#
# 2    ADBS2 Curncy ADBS3 Curncy ADBS5 Curncy ADBS7 Curncy ADBS10 Curncy  ...  \
# 5             NaN          NaN          NaN          NaN           NaN  ...
# 6             NaN          NaN          NaN          NaN           NaN  ...
# 7             NaN          NaN          NaN          NaN           NaN  ...
# 8             NaN          NaN          NaN          NaN           NaN  ...
# 9             NaN          NaN          NaN          NaN           NaN  ...
# ...           ...          ...          ...          ...           ...  ...
# 6327           25        29.13        33.86        35.13        36.875  ...
# 6328           25        29.13        33.86        35.13        36.875  ...
# 6329           25        29.13        33.86        35.13        36.875  ...
# 6330           25        29.13        33.86        35.13        36.875  ...
# 6331           25        29.13        33.86        35.13        36.875  ...
#
# 2    ADSWAP5 Curncy ADSWAP7 Curncy ADSWAP10 Curncy C1273M Index C1271Y Index  \
# 5            7.2375           7.53            7.64         4.92            6
# 6              7.35           7.44            7.55         4.96         6.12
# 7              7.26           7.48            7.58         5.02         6.09
# 8              7.34           7.46            7.56         4.96         6.11
# 9             7.355           7.48            7.59         5.01         6.12
# ...             ...            ...             ...          ...          ...
# 6327         3.9905         4.0845         4.22375       4.1453       3.9205
# 6328        3.98025        4.07775         4.21875       4.1453       3.9205
# 6329        3.98005        4.07755         4.21875       4.1453       3.9205
# 6330        3.98005        4.07755         4.21875       4.1453       3.9205
# 6331         4.0744         4.1822          4.3325       4.1453       3.9205
#
# 2    C1272Y Index C1273Y Index C1275Y Index C1277Y Index C12710Y Index
# 5            6.29         6.47         6.72         6.91          6.97
# 6            6.48         6.66          6.9         7.06          7.14
# 7            6.43         6.61         6.84         6.97          7.05
# 8            6.49         6.68         6.93         7.08          7.13
# 9            6.51         6.71         6.94         7.06          7.12
# ...           ...          ...          ...          ...           ...
# 6327       3.6396       3.5297       3.6183       3.8081        4.0024
# 6328       3.6396       3.5297       3.6183       3.8081        4.0024
# 6329       3.6396       3.5297       3.6183       3.8081        4.0024
# 6330       3.6396       3.5297       3.6183       3.8081        4.0024
# 6331       3.6396       3.5297       3.6183       3.8081        4.0024
#
# [6327 rows x 27 columns]

# %%
df = df.rename(columns={df.columns[0]: 'Timestamp'})
df
# Out:
# 2               Timestamp AUD Curncy AUD3M Curncy BBSW3M Index ADBS1 Curncy  \
# 5     2000-01-03 00:00:00     0.6585         6.75       5.7383          NaN
# 6     2000-01-04 00:00:00      0.655          7.4       5.5717          NaN
# 7     2000-01-05 00:00:00     0.6579         7.59        5.615          NaN
# 8     2000-01-06 00:00:00     0.6533         7.62       5.6067          NaN
# 9     2000-01-07 00:00:00     0.6549         7.41       5.5933          NaN
# ...                   ...        ...          ...          ...          ...
# 6327  2024-03-27 00:00:00     0.6535        16.45       4.3436         19.5
# 6328  2024-03-28 00:00:00     0.6516        16.56       4.3442         19.5
# 6329  2024-03-29 00:00:00     0.6521         16.6       4.3442         19.5
# 6330  2024-04-01 00:00:00     0.6489        16.51       4.3442         19.5
# 6331  2024-04-02 00:00:00     0.6512        16.59       4.3442         19.5
#
# 2    ADBS2 Curncy ADBS3 Curncy ADBS5 Curncy ADBS7 Curncy ADBS10 Curncy  ...  \
# 5             NaN          NaN          NaN          NaN           NaN  ...
# 6             NaN          NaN          NaN          NaN           NaN  ...
# 7             NaN          NaN          NaN          NaN           NaN  ...
# 8             NaN          NaN          NaN          NaN           NaN  ...
# 9             NaN          NaN          NaN          NaN           NaN  ...
# ...           ...          ...          ...          ...           ...  ...
# 6327           25        29.13        33.86        35.13        36.875  ...
# 6328           25        29.13        33.86        35.13        36.875  ...
# 6329           25        29.13        33.86        35.13        36.875  ...
# 6330           25        29.13        33.86        35.13        36.875  ...
# 6331           25        29.13        33.86        35.13        36.875  ...
#
# 2    ADSWAP5 Curncy ADSWAP7 Curncy ADSWAP10 Curncy C1273M Index C1271Y Index  \
# 5            7.2375           7.53            7.64         4.92            6
# 6              7.35           7.44            7.55         4.96         6.12
# 7              7.26           7.48            7.58         5.02         6.09
# 8              7.34           7.46            7.56         4.96         6.11
# 9             7.355           7.48            7.59         5.01         6.12
# ...             ...            ...             ...          ...          ...
# 6327         3.9905         4.0845         4.22375       4.1453       3.9205
# 6328        3.98025        4.07775         4.21875       4.1453       3.9205
# 6329        3.98005        4.07755         4.21875       4.1453       3.9205
# 6330        3.98005        4.07755         4.21875       4.1453       3.9205
# 6331         4.0744         4.1822          4.3325       4.1453       3.9205
#
# 2    C1272Y Index C1273Y Index C1275Y Index C1277Y Index C12710Y Index
# 5            6.29         6.47         6.72         6.91          6.97
# 6            6.48         6.66          6.9         7.06          7.14
# 7            6.43         6.61         6.84         6.97          7.05
# 8            6.49         6.68         6.93         7.08          7.13
# 9            6.51         6.71         6.94         7.06          7.12
# ...           ...          ...          ...          ...           ...
# 6327       3.6396       3.5297       3.6183       3.8081        4.0024
# 6328       3.6396       3.5297       3.6183       3.8081        4.0024
# 6329       3.6396       3.5297       3.6183       3.8081        4.0024
# 6330       3.6396       3.5297       3.6183       3.8081        4.0024
# 6331       3.6396       3.5297       3.6183       3.8081        4.0024
#
# [6327 rows x 27 columns]

# %%
au = df[['Timestamp', 'C1275Y Index']]
au
# Out:
# 2               Timestamp C1275Y Index
# 5     2000-01-03 00:00:00         6.72
# 6     2000-01-04 00:00:00          6.9
# 7     2000-01-05 00:00:00         6.84
# 8     2000-01-06 00:00:00         6.93
# 9     2000-01-07 00:00:00         6.94
# ...                   ...          ...
# 6327  2024-03-27 00:00:00       3.6183
# 6328  2024-03-28 00:00:00       3.6183
# 6329  2024-03-29 00:00:00       3.6183
# 6330  2024-04-01 00:00:00       3.6183
# 6331  2024-04-02 00:00:00       3.6183
#
# [6327 rows x 2 columns]

# %%
plt.plot(au['Timestamp'], au['C1275Y Index'])
plt.grid(True)

# %% [markdown]
# ## Combine all G10 countries and USD

# %%
sheets_dict = pd.read_excel("Data_with_usd.xlsx", sheet_name=None)

# Access each DataFrame using the sheet name as key
df_cad = sheets_dict['CAD']
df_chf = sheets_dict['CHF']

# %%
df_cad.columns = df_cad.iloc[2]
df_cad = df_cad.drop(df_cad.index[:3])
df_cad = df_cad.drop(df_cad.index[:2])
df_cad = df_cad.rename(columns={df_cad.columns[0]: 'Timestamp'})
cad = df_cad[['Timestamp', 'C1015Y Index']]

# %%
df_chf.columns = df_chf.iloc[2]
df_chf = df_chf.drop(df_chf.index[:3])
df_chf = df_chf.drop(df_chf.index[:2])
df_chf = df_chf.rename(columns={df_chf.columns[0]: 'Timestamp'})
chf = df_chf[['Timestamp', 'C2565Y Index']]

# %%
# Access each DataFrame using the sheet name as key
df_usd = sheets_dict['USD']

# Process USD DataFrame
df_usd.columns = df_usd.iloc[2]
df_usd = df_usd.drop(df_usd.index[:3])
df_usd = df_usd.drop(df_usd.index[:2])
df_usd = df_usd.rename(columns={df_usd.columns[0]: 'Timestamp'})
usd = df_usd[['Timestamp', 'C0825Y Index']]  # Replace 'CXXXXY Index' with actual column name for USD

# %%
# Plotting
plt.figure(figsize=(15, 6))
plt.plot(au['Timestamp'], au['C1275Y Index'], label='AUD')
plt.plot(cad['Timestamp'], cad['C1015Y Index'], label='CAD')
plt.plot(chf['Timestamp'], chf['C2565Y Index'], label='CHF')
plt.plot(usd['Timestamp'], usd['C0825Y Index'], label='USD') 
plt.ylabel('Percent')
plt.legend()
plt.grid(True)
plt.savefig('images/fig1a')
plt.show()

# %% [markdown]
# ## Getting the variable: forward premium

# %%
aud_irs = df['ADSWAP5Q Curncy']
aud_bs = df['ADBS5 Curncy'] / 100  # Divide by 100
usd_irs = df_usd['USSW5 Curncy']

# %%
usd_irs = usd_irs.iloc[:-1]

# %%
usd_irs_gfc = usd_irs.iloc[3106:]
usd_irs_gfc
# Out:
# 3111     1.345
# 3112     1.321
# 3113    1.3655
# 3114     1.328
# 3115     1.321
#          ...
# 6327     4.219
# 6328     4.219
# 6329     4.219
# 6330     4.219
# 6331     4.219
# Name: USSW5 Curncy, Length: 3221, dtype: object

# %%
aud_irs_gfc = aud_irs.iloc[3106:]
aud_irs_gfc
# Out:
# 3111     4.225
# 3112      4.18
# 3113     4.226
# 3114    4.2985
# 3115     4.255
#          ...
# 6327    3.8135
# 6328    3.8135
# 6329    3.8135
# 6330    3.8135
# 6331    3.9005
# Name: ADSWAP5Q Curncy, Length: 3221, dtype: object

# %%
aud_bs = aud_bs.dropna()
aud_bs
# Out:
# 3111     0.145
# 3112     0.173
# 3113    0.2125
# 3114     0.213
# 3115     0.209
#          ...
# 6327    0.3386
# 6328    0.3386
# 6329    0.3386
# 6330    0.3386
# 6331    0.3386
# Name: ADBS5 Curncy, Length: 3221, dtype: object

# %%
forward_premium_au = aud_irs_gfc + aud_bs - usd_irs_gfc

# %%
ts = au['Timestamp'][3106:]
ts
# Out:
# 3111    2011-11-29 00:00:00
# 3112    2011-11-30 00:00:00
# 3113    2011-12-01 00:00:00
# 3114    2011-12-02 00:00:00
# 3115    2011-12-05 00:00:00
#                ...
# 6327    2024-03-27 00:00:00
# 6328    2024-03-28 00:00:00
# 6329    2024-03-29 00:00:00
# 6330    2024-04-01 00:00:00
# 6331    2024-04-02 00:00:00
# Name: Timestamp, Length: 3221, dtype: object

# %%
plt.plot(ts, forward_premium_au, label='AUD')

# %% [markdown]
# ## Plot synthetic dollar yields

# %%
au_gfc = au['C1275Y Index'][3106:]

# %%
plt.plot(ts, au_gfc-forward_premium_au, label='AUD')

# %% [markdown]
# ### Get forward premium variables for other countries

# %%
cad_irs = df_cad['CDSW5 Curncy']
cad_bs = df_cad['CDBS5 Curncy'] / 100  # Divide by 100

# %%
cad_bs_gfc = cad_bs[2542:]
cad_bs_gfc
# Out:
# 2547     0.145
# 2548     0.145
# 2549     0.145
# 2550     0.145
# 2551     0.145
#          ...
# 6327   -0.1025
# 6328    -0.115
# 6329    -0.105
# 6330   -0.1075
# 6331    -0.105
# Name: CDBS5 Curncy, Length: 3785, dtype: object

# %%
cad_irs_gfc = cad_irs[2542:]
cad_irs_gfc
# Out:
# 2547    2.6345
# 2548     2.578
# 2549     2.551
# 2550     2.554
# 2551     2.624
#          ...
# 6327    3.8295
# 6328     3.859
# 6329     3.859
# 6330    3.9625
# 6331    3.9753
# Name: CDSW5 Curncy, Length: 3785, dtype: object

# %%
usd_irs = usd_irs.dropna()
usd_irs
# Out:
# 2547    2.6485
# 2548    2.5335
# 2549      2.56
# 2550    2.5805
# 2551     2.619
#          ...
# 6327     4.219
# 6328     4.219
# 6329     4.219
# 6330     4.219
# 6331     4.219
# Name: USSW5 Curncy, Length: 3785, dtype: object

# %%
def get_forward_premium(irs, bs, usirs=usd_irs):
    return irs+bs-usirs


forward_premium_cad = get_forward_premium(cad_irs_gfc, cad_bs_gfc)

# %%
ts_cad = au['Timestamp'][2542:]
ts_cad
# Out:
# 2547    2009-09-30 00:00:00
# 2548    2009-10-01 00:00:00
# 2549    2009-10-02 00:00:00
# 2550    2009-10-05 00:00:00
# 2551    2009-10-06 00:00:00
#                ...
# 6327    2024-03-27 00:00:00
# 6328    2024-03-28 00:00:00
# 6329    2024-03-29 00:00:00
# 6330    2024-04-01 00:00:00
# 6331    2024-04-02 00:00:00
# Name: Timestamp, Length: 3785, dtype: object

# %%
cad_gfc = cad['C1015Y Index'][2542:]

# %%
plt.plot(ts, au_gfc-forward_premium_au, label='AUD')
plt.plot(ts_cad, cad_gfc-forward_premium_cad, label='CAD')
plt.ylabel('Percent')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Forward premium: CHF

# %%
chf_irs = df_chf['SFSW5V3 Curncy']
chf_bs = df_chf['SFBS5 Curncy'] / 100  # Divide by 100

# %%
chf_irs.dropna()
# Out:
# 2548     1.533
# 2549     1.535
# 2550     1.535
# 2551     1.553
# 2552      1.54
#          ...
# 6327   -0.2325
# 6328   -0.2325
# 6329   -0.2325
# 6330   -0.2325
# 6331   -0.2325
# Name: SFSW5V3 Curncy, Length: 3784, dtype: object

# %%
chf_bs.dropna()
# Out:
# 2962   -0.240445
# 2963   -0.241931
# 2964       -0.23
# 2965       -0.23
# 2966       -0.23
#           ...
# 6327     -0.0725
# 6328     -0.0725
# 6329     -0.0725
# 6330     -0.0725
# 6331     -0.0725
# Name: SFBS5 Curncy, Length: 3370, dtype: object

# %%
chf_bs_gfc = chf_bs[2957:]
chf_bs_gfc
# Out:
# 2962   -0.240445
# 2963   -0.241931
# 2964       -0.23
# 2965       -0.23
# 2966       -0.23
#           ...
# 6327     -0.0725
# 6328     -0.0725
# 6329     -0.0725
# 6330     -0.0725
# 6331     -0.0725
# Name: SFBS5 Curncy, Length: 3370, dtype: object

# %%
chf_irs_gfc = chf_irs[2957:]
chf_irs_gfc
# Out:
# 2962    1.5665
# 2963     1.498
# 2964     1.485
# 2965     1.445
# 2966     1.418
#          ...
# 6327   -0.2325
# 6328   -0.2325
# 6329   -0.2325
# 6330   -0.2325
# 6331   -0.2325
# Name: SFSW5V3 Curncy, Length: 3370, dtype: object

# %%
ts_chf = au['Timestamp'][2957:]
ts_chf
# Out:
# 2962    2011-05-04 00:00:00
# 2963    2011-05-05 00:00:00
# 2964    2011-05-06 00:00:00
# 2965    2011-05-09 00:00:00
# 2966    2011-05-10 00:00:00
#                ...
# 6327    2024-03-27 00:00:00
# 6328    2024-03-28 00:00:00
# 6329    2024-03-29 00:00:00
# 6330    2024-04-01 00:00:00
# 6331    2024-04-02 00:00:00
# Name: Timestamp, Length: 3370, dtype: object

# %%
usd_chf = usd_irs[415:]
usd_chf
# Out:
# 2962      2.12
# 2963    2.0676
# 2964     2.054
# 2965    2.0395
# 2966     2.108
#          ...
# 6327     4.219
# 6328     4.219
# 6329     4.219
# 6330     4.219
# 6331     4.219
# Name: USSW5 Curncy, Length: 3370, dtype: object

# %%
forward_premium_chf = get_forward_premium(chf_irs_gfc, chf_bs_gfc, usd_chf)

# %%
chf_gfc = chf['C2565Y Index'][2957:]

# %%
usd['Timestamp'][2537:]
# Out:
# 2542    2009-09-23 00:00:00
# 2543    2009-09-24 00:00:00
# 2544    2009-09-25 00:00:00
# 2545    2009-09-28 00:00:00
# 2546    2009-09-29 00:00:00
#                ...
# 6328    2024-03-28 00:00:00
# 6329    2024-03-29 00:00:00
# 6330    2024-04-01 00:00:00
# 6331    2024-04-02 00:00:00
# 6332    2024-04-03 00:00:00
# Name: Timestamp, Length: 3791, dtype: object

# %%
plt.figure(figsize=(15, 6))
plt.plot(ts, au_gfc-forward_premium_au, label='AUD')
plt.plot(ts_cad, cad_gfc-forward_premium_cad, label='CAD')
plt.plot(ts_chf, chf_gfc-forward_premium_chf, label='CHF')
plt.plot(usd['Timestamp'][2537:], usd['C0825Y Index'][2537:], label='USD') 
plt.ylabel('Percent')
plt.legend()
plt.grid(True)
plt.savefig('images/fig1b')
